# %% [markdown]
# # Lendo o Arquivo CSV via URL

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/superstore_data.csv'

# %%
dados_mercado = pd.read_csv(url, sep=',')
dados_mercado.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dados_mercado.shape
# Out:
# (2240, 22)

# %%
dados_mercado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
dados_mercado.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
dados_selecao = pd.read_csv(url, sep=',', usecols=['Id', 'Year_Birth', 'Income'])

# %%
dados_selecao.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %%
dados_selecao.to_csv('../../data/clientes_mercado.csv', index=False)

# %%
dados  = pd.read_csv('../../data/clientes_mercado.csv')
dados.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %% [markdown]
# # Ler Planilhas

# %%
url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
dados_emissoes = pd.read_excel(url)
dados_emissoes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita = pd.read_excel(url, sheet_name='emissoes_percapita')
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes_emissoes = pd.read_excel(url, sheet_name='fontes')

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02', usecols= 'A:D', nrows=10) # seleciona as colunas A até D e as 10 primeiras linhas
intervalo
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
intervalo.to_excel('../../data/dados_intervalos.xlsx', index=False)

# %% [markdown]
# #### Lendo Arquvios JSON

# %%
url_json = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes.json'

# %%
dados_pacientes = pd.read_json(url_json)
dados_pacientes.head()
# Out:
#    ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0            0             Nao  16.60     Sim            Nao  Nao
# 1            1             Nao  20.34     Nao            Nao  Sim
# 2            2             Nao  26.58     Sim            Nao  Nao
# 3            3             Nao  24.21     Nao            Nao  Nao
# 4            4             Nao  23.71     Nao            Nao  Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0             3            30                  Nao       Feminino
# 1             0             0                  Nao       Feminino
# 2            20            30                  Nao      Masculino
# 3             0             0                  Nao       Feminino
# 4            28             0                  Sim       Feminino
#
#   Faixa_etaria    Raca Diabetes Atividade_fisica Saude_geral  Horas_sono Asma  \
# 0        55-59  Branca      Sim              Sim   Muito boa           5  Sim
# ...

# %%
url_json_2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes_2.json'

# %%
dados_pacientes_2 = pd.read_json(url_json_2)
dados_pacientes_2.head()
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
# normalizando os dados json  
dados_pacientes_normalizados = pd.json_normalize(dados_pacientes_2['Pacientes'])
dados_pacientes_normalizados
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
dados_pacientes_normalizados.to_json('../../data/pacientes_normalizados.json', orient='records')

# %% [markdown]
# #### Desafio chegou a hora de testar os conhecimentos desenvolvidos durante a aula.

# %% [markdown]
#  Este DataFrame possui 8 colunas: id, name (nome), username (nome de usuário), email , address (endereço), phone(telefone), website e company (empresa). Note que as colunas address e company contém informações aninhadas, ou seja, os dados dessas colunas estão organizados em subcampos. Por exemplo, na coluna address, você encontrará subcampos como street (rua), suite (complemento), city (cidade) e zipcode (CEP). Já na coluna company, os subcampos incluem name (nome da empresa), catchPhrase (slogan) e bs (área de atuação). Isso significa que, para acessar essas informações, é necessário realizar o processo de normalização.
#
# O desafio agora é normalizar esse DataFrame, expandindo as colunas address e company em suas respectivas subcolunas para facilitar a visualização e a análise dos dados.

# %%
import requests
import json

dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users')
resultado = json.loads(dados_usuarios.text)
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
# ...

# %%
dados_usuarios_normalizado = pd.json_normalize(resultado)

# %%
dados_usuarios_normalizado
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address.street address.suite  \
# ...

# %% [markdown]
# ### Manipulando Arquivo em HTML

# %%
caminho_html = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/filmes_wikipedia.html'

# %%
dados_filmes = pd.read_html(caminho_html)
top_filmes = dados_filmes[1]

# %%
top_filmes
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %%
top_filmes.to_html('../../data/top_filmes.html', index=False)

# %%
top_filmes.to_csv('../../data/top_filmes.csv', index=False)

# %% [markdown]
# #### Manipulando Arquivos XML

# %%
caminho_xml = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/imdb_top_1000.xml'

# %%
dados_imdb = pd.read_xml(caminho_xml)
dados_imdb.head()
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %%
dados_imdb.to_xml('../../data/imdb_top_1000.xml', index=False)

# %% [markdown]
# #### Manipulando Banco de Dados

# %%
! pip install sqlalchemy

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine('sqlite:///:memory:')

# %%
url_clientes  = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/clientes_banco.csv'

# %%
dados_clientes = pd.read_csv(url_clientes)
dados_clientes
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
dados_clientes.to_sql('clientes', con=engine)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query = 'Select * from clientes where Categoria_de_renda = "Empregado"	'

# %%
empregados = pd.read_sql_query(query, engine)
empregados
# Out:
#          index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0            0     5008804     32   Ensino superior  União-estável
# 1            1     5008805     32   Ensino superior  União-estável
# 2            2     5008806     58      Ensino médio         Casado
# 3           10     5008815     46   Ensino superior         Casado
# 4           11     5112956     46   Ensino superior         Casado
# ...        ...         ...    ...               ...            ...
# 226054  438448     6837905     43      Ensino médio         Casado
# 226055  438449     6837906     43      Ensino médio         Casado
# 226056  438454     6839936     34      Ensino médio         Casado
# 226057  438459     6840222     43      Ensino médio       Solteiro
# 226058  438462     6842885     51      Ensino médio         Casado
#
#         Tamanho_familia Categoria_de_renda          Ocupacao  Anos_empregado  \
# 0                     2          Empregado             Outro              12
# ...

# %%
empregados.to_sql('empregados', con=engine)
# Out:
# 226059

# %%
pd.read_sql_table('empregados', engine)
# Out:
#         level_0   index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0             0       0     5008804     32   Ensino superior  União-estável
# 1             1       1     5008805     32   Ensino superior  União-estável
# 2             2       2     5008806     58      Ensino médio         Casado
# 3             3      10     5008815     46   Ensino superior         Casado
# 4             4      11     5112956     46   Ensino superior         Casado
# ...         ...     ...         ...    ...               ...            ...
# 226054   226054  438448     6837905     43      Ensino médio         Casado
# 226055   226055  438449     6837906     43      Ensino médio         Casado
# 226056   226056  438454     6839936     34      Ensino médio         Casado
# 226057   226057  438459     6840222     43      Ensino médio       Solteiro
# 226058   226058  438462     6842885     51      Ensino médio         Casado
#
# ...

# %%
pd.read_sql_table('empregados', engine, columns=['ID_Cliente', 'Grau_escolaridade', 'Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
# utilizar o TEXT
query = 'Delete from clientes where ID_Cliente=5008804'
with engine.connect() as con:
    con.execute(text(query))

# %%
pd.read_sql_table('clientes', engine)
# Out:
#          index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0            0     5008804     32   Ensino superior  União-estável
# 1            1     5008805     32   Ensino superior  União-estável
# 2            2     5008806     58      Ensino médio         Casado
# 3            3     5008808     52      Ensino médio       Solteiro
# 4            4     5008809     52      Ensino médio       Solteiro
# ...        ...         ...    ...               ...            ...
# 438458  438458     6840104     62      Ensino médio     Divorciado
# 438459  438459     6840222     43      Ensino médio       Solteiro
# 438460  438460     6841878     22   Ensino superior       Solteiro
# 438461  438461     6842765     59      Ensino médio         Casado
# 438462  438462     6842885     51      Ensino médio         Casado
#
#         Tamanho_familia   Categoria_de_renda          Ocupacao  \
# 0                     2            Empregado             Outro
# ...

# %%
query = 'UPDATE clientes SET Grau_escolaridade="Ensino superior" WHERE ID_Cliente=5008808' 
with engine.connect() as con:
    con.execute(text(query))
    con.commit()

# %%
executar = pd.read_sql_table('clientes', engine)

# %% [markdown]
# #### Desafio SQL

# %%
query = 'UPDATE clientes SET Rendimento_anual=3000 WHERE ID_Cliente=6840104' 
with engine.connect() as con:
    con.execute(text(query))
    con.commit()

# %%
executar
# Out:
#          index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0            0     5008804     32   Ensino superior  União-estável
# 1            1     5008805     32   Ensino superior  União-estável
# 2            2     5008806     58      Ensino médio         Casado
# 3            3     5008808     52   Ensino superior       Solteiro
# 4            4     5008809     52      Ensino médio       Solteiro
# ...        ...         ...    ...               ...            ...
# 438458  438458     6840104     62      Ensino médio     Divorciado
# 438459  438459     6840222     43      Ensino médio       Solteiro
# 438460  438460     6841878     22   Ensino superior       Solteiro
# 438461  438461     6842765     59      Ensino médio         Casado
# 438462  438462     6842885     51      Ensino médio         Casado
#
#         Tamanho_familia   Categoria_de_renda          Ocupacao  \
# 0                     2            Empregado             Outro
# ...

# %%
# utilizar o TEXT
query = 'Delete from clientes where ID_Cliente=5008809'
with engine.connect() as con:
    con.execute(text(query))

# %%
executar
# Out:
#          index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0            0     5008804     32   Ensino superior  União-estável
# 1            1     5008805     32   Ensino superior  União-estável
# 2            2     5008806     58      Ensino médio         Casado
# 3            3     5008808     52   Ensino superior       Solteiro
# 4            4     5008809     52      Ensino médio       Solteiro
# ...        ...         ...    ...               ...            ...
# 438458  438458     6840104     62      Ensino médio     Divorciado
# 438459  438459     6840222     43      Ensino médio       Solteiro
# 438460  438460     6841878     22   Ensino superior       Solteiro
# 438461  438461     6842765     59      Ensino médio         Casado
# 438462  438462     6842885     51      Ensino médio         Casado
#
#         Tamanho_familia   Categoria_de_renda          Ocupacao  \
# 0                     2            Empregado             Outro
# ...

# %%
query = 'INSERT INTO clientes (ID_Cliente, Idade, Grau_escolaridade, Estado_civil, ' \
        'Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, ' \
        'Rendimento_anual, Tem_carro, Moradia) ' \
        'VALUES (6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", ' \
        '2, 290000, 0, "Casa/apartamento próprio")'

with engine.connect() as conn:
  result = conn.execute(text(query))
  conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#            index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0            0.0     5008804     32   Ensino superior  União-estável
# 1            1.0     5008805     32   Ensino superior  União-estável
# 2            2.0     5008806     58      Ensino médio         Casado
# 3            3.0     5008808     52   Ensino superior       Solteiro
# 4            4.0     5008809     52      Ensino médio       Solteiro
# ...          ...         ...    ...               ...            ...
# 438459  438459.0     6840222     43      Ensino médio       Solteiro
# 438460  438460.0     6841878     22   Ensino superior       Solteiro
# 438461  438461.0     6842765     59      Ensino médio         Casado
# 438462  438462.0     6842885     51      Ensino médio         Casado
# 438463       NaN     6850985     33         Doutorado       Solteiro
#
#         Tamanho_familia   Categoria_de_renda          Ocupacao  \
# 0                     2            Empregado             Outro
# ...
